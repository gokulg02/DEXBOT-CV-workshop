# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Playing video

# %%
cap = cv2.VideoCapture(r"C:\Users\Vasumathi T\Downloads\Input (online-video-cutter.com).mp4")
while(cap.isOpened()):
    ret, frame = cap.read()
    if ret == True:
        cv2.imshow('Frame',frame)
        cv2.waitKey(10)
    else:
        break
cv2.destroyAllWindows()
cap.release()

# %% [markdown]
# Converting video into frames

# %%
currentframe = 0
cap = cv2.VideoCapture(r"C:\Users\Vasumathi T\Downloads\Input (online-video-cutter.com).mp4") 
while(True):
    ret,frame = cap.read()
    if ret:
        name = r'data/vid_img/frame'+str(currentframe)+'.jpg'
        #print ('Creating...' + name)
        cv2.imwrite(name, frame)
        currentframe += 1
    else:
        break
cap.release()

# %% [markdown]
# Finding edge points

# %%
f= cv2.imread(r'data/vid_img/frame55.jpg')
image = cv2.circle(f, (7,149), radius=0, color=(0, 0, 255), thickness=10) #A
image = cv2.circle(f, (255,10), radius=0, color=(0, 255, 0), thickness=10) #B
image = cv2.circle(f, (533,91), radius=0, color=(255, 0, 0), thickness=10) #C
image = cv2.circle(f, (321,329), radius=0, color=(0, 100, 100), thickness=10) #D
plt.imshow(image)

# %% [markdown]
# Applying perspective transform

# %%
def prespective_transform(img):
    source = np.float32([[7,149],[255,10],[321,329],[533,91]])
    destination = np.float32([[0,0],[300,0],[0,300],[300,300]])
    transformMatrix = cv2.getPerspectiveTransform(source, destination)
    transformedImg = cv2.warpPerspective(img,transformMatrix,(300,300))
    return transformedImg

# %%
f= cv2.imread(r'data/vid_img/frame55.jpg')
pt_img = prespective_transform(f)
plt.imshow(pt_img[:,:,::-1])

# %% [markdown]
# Converting to HSV colorspace

# %%
def conv_hsv(img):
    img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    return img

# %%
hsv_img = conv_hsv(pt_img)
plt.imshow(hsv_img[:,:,0],cmap='gray')

# %% [markdown]
# Thresholding of 'h' component

# %%
plt.hist(np.ravel(hsv_img[:,:,0]))
# Out:
# (array([1.2200e+02, 2.7000e+01, 7.5660e+03, 5.9090e+03, 1.5150e+03,
#         7.4533e+04, 1.7000e+01, 1.2800e+02, 1.2700e+02, 5.6000e+01]),
#  array([108. , 109.4, 110.8, 112.2, 113.6, 115. , 116.4, 117.8, 119.2,
#         120.6, 122. ]),
#  <BarContainer object of 10 artists>)

# %%
def thresh(img):
    mask = img[:,:,0]<90
    return mask

# %%
mask = thresh(hsv_img)
plt.imshow(mask,cmap='gray')

# %% [markdown]
# Find centre point of ball in mask

# %%
def centre_pt(mask):
    mask = mask *255
    mask = np.uint8(mask)
    ret, thresh = cv2.threshold(mask, 50, 255, cv2.THRESH_BINARY)
    contours, hierarchy = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    if contours == ():
        return None, None
    try:
        M = cv2.moments(contours[0])
        cX = int(M["m10"] / M["m00"])
        cY = int(M["m01"] / M["m00"])
    except:
        return None, None
    return cX,cY

# %%
cX,cY = centre_pt(mask)
centre_pt(mask)
# Out:
# (None, None)

# %% [markdown]
# Find region of ball

# %%
def find_region(cX,cY):
    if cX== None and cY==None:
        return '-'
    if cX<150 and cY<150:
        return 1
    elif cX<150 and cY>150:
        return 3
    elif cX>150 and cY<150:
        return 2
    else:
        return 4

# %%
r = find_region(cX,cY)

# %% [markdown]
# Marking on image

# %%
def disp(img,r):
    img = cv2.line(img, (0,0), (0,300), (255,0,0), 5)
    img = cv2.line(img, (0,0), (300,0), (255,0,0), 5)
    img = cv2.line(img, (0,300), (300,300), (255,0,0), 5)
    img = cv2.line(img, (300,0), (300,300), (255,0,0), 5)
    img = cv2.line(img, (0,150), (300,150), (255,0,0), 5)
    img = cv2.line(img, (150,0), (150,300), (255,0,0), 5)
    img = cv2.putText(img, str(r), (5,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2, cv2.LINE_AA)
    return img

# %%
final_img = disp(pt_img,r)
plt.imshow(final_img[:,:,::-1])

# %% [markdown]
# Combining into a single function

# %%
def final(img):
    try:
        pt_img = prespective_transform(img)
        hsv_img = conv_hsv(pt_img)
        mask = thresh(hsv_img)
        cX,cY = centre_pt(mask)
        r = find_region(cX,cY)
        final_img = disp(pt_img,r)
    except:
        return None , False
    return final_img, True

# %%
img = cv2.imread(r'data/vid_img/frame55.jpg')
final_img, ret = final(img)
plt.imshow(final_img[:,:,::-1])

# %% [markdown]
# Testing on video

# %%
cap = cv2.VideoCapture(r"C:\Users\Vasumathi T\Downloads\Input (online-video-cutter.com).mp4")
while(cap.isOpened()):
    ret, frame = cap.read()
    frame, ret2 = final(frame)
    if ret2==False:
        continue
    elif ret == True and ret2==True:
        cv2.imshow('Frame',frame)
        cv2.waitKey(10)
    else:
        break
cv2.destroyAllWindows()
cap.release()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [18], in final(img)
#       2 try:
# ----> 3     pt_img = prespective_transform(img)
#       4     hsv_img = conv_hsv(pt_img)
#
# Input In [5], in prespective_transform(img)
#       4 transformMatrix = cv2.getPerspectiveTransform(source, destination)
# ----> 5 transformedImg = cv2.warpPerspective(img,transformMatrix,(300,300))
#       6 return transformedImg
#
# error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\imgwarp.cpp:3144: error: (-215:Assertion failed) _src.total() > 0 in function 'cv::warpPerspective'
#
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [20], in <cell line: 2>()
#       2 while(cap.isOpened()):
#       3     ret, frame = cap.read()
# ----> 4     frame, ret2 = final(frame)
#       5     if ret2==False:
#       6         continue
#
# Input In [18], in final(img)
#       1 def final(img):
#       2     try:
# ----> 3         pt_img = prespective_transform(img)
#       4         hsv_img = conv_hsv(pt_img)
#       5         mask = thresh(hsv_img)
#
# KeyboardInterrupt:
