# %%
import numpy as np 
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# __Manual Thresholding__

# %%
img = cv2.imread(r"data\boat.jpg")

# %%
img.shape
# Out:
# (514, 768, 3)

# %%
img = img[:,:,0]

# %%
plt.imshow(img, cmap = 'gray')

# %%
plt.hist(np.ravel(img))
# Out:
# (array([  6758.,   2265.,   3485.,   2968.,   1479.,    981.,  20313.,
#          77390., 175068., 104045.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <BarContainer object of 10 artists>)

# %%
mask = img < 150

# %%
plt.imshow(mask, cmap = 'gray');

# %%
img_thresh = mask*img

# %%
f, ax = plt.subplots(2,2,figsize=(10, 10))
ax[0,0].imshow(img, cmap = 'gray')
ax[0,1].hist(np.ravel(img))
ax[1,0].imshow(img_thresh, cmap = 'gray')
ax[1,1].hist(np.ravel(img_thresh))
# Out:
# (array([380867.,   3283.,   1352.,   1414.,   2269.,   1805.,   1787.,
#            832.,    568.,    575.]),
#  array([  0. ,  14.9,  29.8,  44.7,  59.6,  74.5,  89.4, 104.3, 119.2,
#         134.1, 149. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# __Automatic Thresholding__

# %%
ret,mask = cv2.threshold(img,0,1,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)

# %%
plt.imshow(mask, cmap = 'gray');

# %%
img_thresh = mask*img

# %%
f, ax = plt.subplots(2,2,figsize=(10, 10))
ax[0,0].imshow(img, cmap = 'gray')
ax[0,1].hist(np.ravel(img))
ax[1,0].imshow(img_thresh, cmap = 'gray')
ax[1,1].hist(np.ravel(img_thresh))
# Out:
# (array([381066.,   3423.,   1260.,   1045.,   1604.,   2099.,   1443.,
#           1580.,    709.,    523.]),
#  array([  0. ,  13.2,  26.4,  39.6,  52.8,  66. ,  79.2,  92.4, 105.6,
#         118.8, 132. ]),
#  <BarContainer object of 10 artists>)
